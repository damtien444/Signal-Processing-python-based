# %%
from thinkdsp import*

# %%
wave = read_wave("violin-origional.wav")
print('Number of samples', len(wave.ys))
print('Time in second', 1 / wave.framerate * len(wave.ys))
# Out:
# Number of samples 220500
# Time in second 5.0

# %%
wave.plot()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-6bf86b783c33> in <module>
# ----> 1 newwave = wave.make_wave(5, 0, wave.framerate/2)
#
# AttributeError: 'Wave' object has no attribute 'make_wave'
