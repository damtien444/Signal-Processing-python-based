# %% [markdown]
# # Problem 8

# %% [markdown]
# A 5-point moving average filter computes a simple average over five input samples at
# each n.
#
# * (a) Determine the difference equation for this filter.
#
# * (b) Determine and plot the impulse response $h[n]$.
#
# * (c) Draw the system block diagram.

# %% [markdown]
# ## Section a:

# %% [markdown]
# According to the formula of *the moving average filter* that has been mentioned in example about ***Recursive FIR system*** at page 66 in the textbook, we have:

# %% [markdown]
# $y\left [ n \right ] = \frac{1}{M+1}\sum_{k=0}^{M}x\left [ n-k \right ]$

# %% [markdown]
# In the 5-point moving average filter, the difference equation would be:

# %% [markdown]
# $y\left [ n \right ] = \frac{1}{4+1}\sum_{k=0}^{4}x\left [ n-k \right ]$

# %% [markdown]
# $y\left [ n \right ] = \frac{1}{5}\left ( x\left [ n \right ] +x\left [ n-1 \right ]+x\left [ n-2 \right ] +x\left [ n-3 \right ]+x\left [ n-4\right ]\right )$

# %% [markdown]
# ## Section b:

# %% [markdown]
# **Suppose we insert an impulse:**

# %% [markdown]
# $x\left [ n \right ] = \delta \left [ n \right ]$

# %% [markdown]
# **Then by definition, whaterver we get at the output is the impulse response**

# %% [markdown]
# $ h\left [ n \right ] = \frac{1}{5}\left ( \delta\left [ n \right ] +\delta\left [ n-1 \right ]+\delta\left [ n-2 \right ] +\delta\left [ n-3 \right ]+\delta\left [ n-4\right ]\right )$

# %% [markdown]
# $\Rightarrow h\left [ n \right ] =  \begin{cases}
#  \frac{1}{5} & \text{ if } n= 0,1,2,3,4\\
#  0& \text{ otherwise}
# \end{cases}$

# %% [markdown]
# **Plot of the impulse response**

# %%
import numpy as np
import matplotlib.pyplot as plt

def h(n):
    if n<=4 and n>=0:
        return 1/5
    else:
        return 0

sample = [h(i) for i in range(-1, 11)]

fig = plt.figure()
fig.set_size_inches(12,6)
plt.subplots_adjust(hspace=1)
plt.stem(range(-1, 11, 1), sample)
plt.title('The impulse response h[n] of 5-point average filter')
plt.xlabel('n')
plt.ylabel('h[n]')
# Out:
# Text(0, 0.5, 'h[n]')

# %% [markdown]
# ## Section c:

# %% [markdown]
# According to the basic building blocks indicated at page 36 of the textbook, we have this block diagram:

# %% [markdown]
# At this section, I use powerpoint to generate the diagram for simplicity purposes.

# %% [markdown]
# <img src="diagram.png">

# %%
# import scipy.signal

# def u(n):
#     res = []
#     for i in n:
#         if i>=0:
#             res.append(1)
#         else:
#             res.append(0)
#     return res

    
# n = np.arange(1, 5)    
# xn = np.array(u(n))
# scipy.signal.lfilter(np.ones((1,5))/5,1,xn)
# # print(np.ones((1,5))/5)

# %%
# from scipy import signal
# t, y = signal.impulse(([1,1,1,1,1], [1]))
# import matplotlib.pyplot as plt
# plt.stem(t, y)

# %%
x1 = np.random.randn(20) # Tín hiệu ngẫu nhiên
x2 = np.random.randn(20) 

a1 = np.random.randn()
a2 = np.random.randn()
# hệ số ngẫu nhiên

x = a1*x1 + a2*x2

y = lambda x: x*x



fig = plt.figure()
fig.set_size_inches(12,6)
plt.subplots_adjust(hspace=1)

plt.subplot()
plt.plot(a1*y(x1)+a2*y(x2))
# plt.subplot(122)
plt.plot(y(x))

plt.title('y(n) = x^2(n)')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Comment
#
# Hệ thống không tuyến tính

# %%
n1 = np.random.randn(20) # Tín hiệu ngẫu nhiên
n2 = np.random.randn(20) 

a1 = np.random.randn()
a2 = np.random.randn()
# hệ số ngẫu nhiên

x1 = n1*n1
x2 = n2*n2

x = a1*x1 + a2*x2

y = lambda x: x



fig = plt.figure()
fig.set_size_inches(12,6)
plt.subplots_adjust(hspace=1)

plt.subplot(121)
plt.plot(a1*y(x1)+a2*y(x2))
plt.title("y(x) = a1*y(x1) + a2*y(x2)")
plt.xlabel('x')
plt.ylabel('y')


plt.subplot(122)
plt.plot(y(x))

plt.title("y(x) với x=n^2")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Comment:
# Cái này tuyến tính!

# %%
def y(t):
    return 6*np.cos(2*np.pi*1000*t)+4*np.cos(2*np.pi*2000*t)

# %matplotlib tk


time = []
for i in range(1,1000):
    time.append(i/1000)
    
res = []
for i in range(len(time)):
    res.append(y(time[i]))


plt.plot(time, res)
res
# Out:
# [10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
# ...
